# %% [markdown]
# ### MALE FEMALE BIASES CALCULATION

# %% [markdown]
# ### import necessariy modules

# %%
import json
import glob
import traceback
from gensim.models import KeyedVectors
from calculate_distance import CalculateDistance
from calculate_bias import calculate_bias_for_all_embedding
from utils import populate_b2e_dict_for_words
from word_sets_arabic import MALE_WORDS_ARABIC, FEMALE_WORDS_ARABIC, PROFESSIONAL_OCCUPATIONS_ARABIC, PROFESSIONAL_OCCUPATIONS_ENGLISH
from plot_utils import get_association_subplot, get_bias_plot, get_correlation_heatmap

# %% [markdown]
# ### load male, female & professional occupation wordlist

# %%
target_groups = [PROFESSIONAL_OCCUPATIONS_ARABIC]
target_group_labels = ['professional_occupation']

reference_groups = [MALE_WORDS_ARABIC, FEMALE_WORDS_ARABIC]
reference_group_labels = ['male', 'female']

print('target group -->')
for group, labels in zip(target_groups, target_group_labels):
    print(labels, group)

print('reference group -->')
for group, labels in zip(reference_groups, reference_group_labels):
    print(labels, group)



b2e_dict = populate_b2e_dict_for_words(PROFESSIONAL_OCCUPATIONS_ARABIC, PROFESSIONAL_OCCUPATIONS_ENGLISH)
# Out:
# target group -->
# professional_occupation ['إحصائي', 'مصور', 'رياضي', 'راقصة', 'مدبرة منزل', 'محاسب', 'فيزيائي', 'حائك', 'نجار', 'عالم نفسي', 'حارس', 'عالم رياضيات', 'مساح', 'خياط', 'مصمم', 'اقتصادي', 'عامل', 'وسيط', 'أمين مكتبة', 'موسيقي', 'حمال', 'عالم', 'مهندس معماري', 'مشغل', 'جراح', 'سائق', 'موصل', 'ممرضة', 'كوك', 'مهندس', 'محام', 'مزارع', 'كاتب', 'مدير', 'فنان', 'شرطة', 'طبيب', 'أستاذ', 'قاضي', 'معلم', 'كاتب', 'سكرتير', 'الجندي', 'النائب']
# reference group -->
# male ['الابن', 'الابن', 'الأب', 'الأب', 'الأب', 'الرجل', 'الجد', 'الأخ', 'العم', 'العم', 'ابن أخ']
# female ['ابنة', 'فتاة', 'أم', 'أم', 'امرأة', 'بنات', 'أخت', 'أخت', 'عمة', 'عمة', 'ابنة']

# %%
calculate_association_distance = CalculateDistance()
calculate_association_distance.set_target_word_groups(target_word_groups=target_groups, target_group_labels=target_group_labels)
calculate_association_distance.set_reference_word_groups(reference_word_groups=reference_groups, reference_group_labels=reference_group_labels)

# %%
association_dict = {}
model_dir = '../word_embeddings/arabic_embeddings/'
filenames = glob.glob(model_dir + '*bin')

print(filenames)
for filename in filenames:
    newspaper_name = filename.split('/')[-1].split('_')[0]
    target_wise_association_for_this_paper = {}
    model = KeyedVectors.load_word2vec_format(filename, binary=True)
    target_wise_association_for_this_paper = calculate_association_distance.get_association_for_provided_embedding(model=model)
    association_dict[newspaper_name] = target_wise_association_for_this_paper
    
    get_association_subplot(target_wise_association_for_this_paper=target_wise_association_for_this_paper, b2e_dict = b2e_dict, title= newspaper_name)

# print(association_dict)
# Out:
# ['../word_embeddings/arabic_embeddings/arabic-twitter_full_uni_cbow_300_twitter.bin', '../word_embeddings/arabic_embeddings/arabic-wiki_full_uni_cbow_300_wiki.bin']
# word الأب not in embedding
# word الأب not in embedding
# word الأب not in embedding
# word الأخ not in embedding
# word ابن أخ not in embedding
# word إحصائي not in embedding
# word راقصة not in embedding
# word مدبرة منزل not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word أمين مكتبة not in embedding
# word مهندس معماري not in embedding
# word ممرضة not in embedding
# word شرطة not in embedding
# word أستاذ not in embedding
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأب' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأب' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأب' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأخ' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ابن أخ' not in vocabulary"
# word ابنة not in embedding
# word فتاة not in embedding
# word أم not in embedding
# word أم not in embedding
# word امرأة not in embedding
# word أخت not in embedding
# word أخت not in embedding
# word عمة not in embedding
# word عمة not in embedding
# word ابنة not in embedding
# word إحصائي not in embedding
# word راقصة not in embedding
# word مدبرة منزل not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word أمين مكتبة not in embedding
# word مهندس معماري not in embedding
# word ممرضة not in embedding
# word شرطة not in embedding
# word أستاذ not in embedding
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ابنة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'فتاة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أم' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أم' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'امرأة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أخت' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أخت' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'عمة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'عمة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ابنة' not in vocabulary"
# word الأب not in embedding
# word الأب not in embedding
# word الأب not in embedding
# word الأخ not in embedding
# word ابن أخ not in embedding
# word إحصائي not in embedding
# word راقصة not in embedding
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأب' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأب' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأب' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأخ' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ابن أخ' not in vocabulary"
# word مدبرة منزل not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word أمين مكتبة not in embedding
# word مهندس معماري not in embedding
# word ممرضة not in embedding
# word شرطة not in embedding
# word أستاذ not in embedding
# word ابنة not in embedding
# word فتاة not in embedding
# word أم not in embedding
# word أم not in embedding
# word امرأة not in embedding
# word أخت not in embedding
# word أخت not in embedding
# word عمة not in embedding
# word عمة not in embedding
# word ابنة not in embedding
# word إحصائي not in embedding
# word راقصة not in embedding
# word مدبرة منزل not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word أمين مكتبة not in embedding
# word مهندس معماري not in embedding
# word ممرضة not in embedding
# word شرطة not in embedding
# word أستاذ not in embedding
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ابنة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'فتاة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أم' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أم' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'امرأة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أخت' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أخت' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'عمة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'عمة' not in vocabulary"
# Traceback (most recent call last):
#   File "/home/saurav_workspace/newspaper-biasness-analysis/calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ابنة' not in vocabulary"

# %% [markdown]
# ### Calculate female bias for all embedding

# %%
print( association_dict)
from plot_utils import get_bias_plot
male_bias_dict_for_all_embeddings = calculate_bias_for_all_embedding(association_dict=association_dict, 
                                                                     target_label = target_group_labels[0], 
                                                                     reference_labels = reference_group_labels)

get_bias_plot(bias_dict=male_bias_dict_for_all_embeddings, b2e_dict=b2e_dict, bias_label = reference_group_labels[1])
# Out:
# {'arabic-twitter': {'professional_occupation': {'male': {'موسيقي': 1.057039376348257, 'مشغل': 1.0523113049566746, 'محاسب': 0.9765829257667065, 'جراح': 0.9648623801767826, 'عالم': 0.9620710350573063, 'وسيط': 0.9439754486083984, 'اقتصادي': 0.9385653957724571, 'رياضي': 0.9318578839302063, 'موصل': 0.9235785976052284, 'كاتب': 0.9121007844805717, 'مزارع': 0.9083952605724335, 'مصور': 0.9067497700452805, 'عامل': 0.8952644541859627, 'فيزيائي': 0.8929485157132149, 'حمال': 0.8875662088394165