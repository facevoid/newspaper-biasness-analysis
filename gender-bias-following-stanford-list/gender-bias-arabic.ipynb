# %% [markdown]
# ### MALE FEMALE BIASES CALCULATION

# %%
import sys 
sys.path.append('..')

import json
import glob
import traceback
from gensim.models import KeyedVectors
from calculate_distance import CalculateDistance
from calculate_bias import calculate_bias_for_all_embedding
from utils import populate_b2e_dict_for_words
from plot_utils import get_association_subplot, get_bias_plot, get_correlation_heatmap

#CHANGE BELOW TWO LINE WITH
from word_sets_stanford_standards import MALE_WORDS_ARABIC as MALE_WORDS, FEMALE_WORDS_ARABIC as FEMALE_WORDS, PROFESSIONAL_OCCUPATIONS_ARABIC as PROFESSIONAL_OCCUPATIONS, PROFESSIONAL_OCCUPATIONS_ENGLISH
MODEL_DIR = '../../word_embeddings/arabic_embeddings/'

# %% [markdown]
# ### load male, female & professional occupation wordlist

# %%
target_groups = [PROFESSIONAL_OCCUPATIONS]
target_group_labels = ['professional_occupation']

reference_groups = [MALE_WORDS, FEMALE_WORDS]
reference_group_labels = ['male', 'female']

print('target group -->')
for group, labels in zip(target_groups, target_group_labels):
    print(labels, group)

print('reference group -->')
for group, labels in zip(reference_groups, reference_group_labels):
    print(labels, group)



b2e_dict = populate_b2e_dict_for_words(PROFESSIONAL_OCCUPATIONS, PROFESSIONAL_OCCUPATIONS_ENGLISH)
# Out:
# target group -->
# professional_occupation ['حارس', 'خبير إحصائي', 'قابلة', 'محضّر', 'مزايد', 'مصور', 'جيولوجي', 'صانع أحذية', 'رياضي', 'أمين صندوق', 'راقصة', 'مدبرة منزل', 'محاسب', 'فيزيائي', 'بستاني', 'طبيب أسنان', 'حائك', 'حداد', 'عالم نفسي', 'مشرف', 'عالم رياضيات', 'مساح', 'خياط', 'مصمم', 'اقتصادي', 'ميكانيكي', 'عامل', 'مدير مكتب بريد', 'وسيط', 'كيميائي', 'أمين مكتبة', 'كاتب', 'كتابي', ' موسيقي ', ' حمال ', ' عالم ', ' نجار ', ' بحار ', ' مدرب ', ' شريف ', ' رائد ', ' مفتش ', ' ماسون ', 'خباز', 'مسؤول', 'مهندس', 'جامع', 'عامل تشغيل', 'جراح', 'سائق', 'رسام', 'موصل', 'ممرضة', 'طبخ', 'مهندس', 'متقاعد', 'مبيعات', 'محام', 'رجل دين', 'طبيب', 'مزارع', 'كاتب', 'مدير', 'حارس', 'فنان', 'سميث', 'مسؤول', 'شرطة', 'طبيب', 'أستاذ', 'طالب', 'قاضي', 'معلم', 'كاتب', 'سكرتير', 'جندي']
# reference group -->
# male ['هو', 'الابن', 'له', 'هو', 'الأب', 'الرجل', 'الصبي', 'نفسه', 'الذكر', 'الأخ', 'الأبناء', 'الآباء', 'الرجال', 'الأولاد', 'الذكور', 'الإخوة', 'العم']
# female ['هي', 'ابنة', 'راتبها', 'لها', 'أم', 'امرأة', 'فتاة', 'نفسها', 'أنثى', 'أخت', 'بنات', 'أمهات', ' نساء', 'البنات', 'المنيعة', 'الأخوات', 'العمة', 'العمات', 'الأخوات', 'الأخوات']

# %%
calculate_association_distance = CalculateDistance()
calculate_association_distance.set_target_word_groups(target_word_groups=target_groups, target_group_labels=target_group_labels)
calculate_association_distance.set_reference_word_groups(reference_word_groups=reference_groups, reference_group_labels=reference_group_labels)

# %% [markdown]
# ### Calculate associations

# %%
association_dict = {}
model_dir = MODEL_DIR
filenames = glob.glob(model_dir + '*')
print(filenames)
for filename in filenames:
    embedding_name = filename.split('/')[-1]
    target_wise_association_for_this_paper = {}
    if embedding_name.split('.')[-1] == 'bin':
        model = KeyedVectors.load_word2vec_format(filename, binary=True)
    else:
        model = KeyedVectors.load_word2vec_format(filename, binary=False)
    target_wise_association_for_this_embedding = calculate_association_distance.get_association_for_provided_embedding(model=model)
    association_dict[embedding_name] = target_wise_association_for_this_embedding
    print(association_dict)
    
    get_association_subplot(target_wise_association_for_this_paper=target_wise_association_for_this_embedding, b2e_dict = b2e_dict, title= embedding_name)
# Out:
# ['../../word_embeddings/arabic_embeddings/arabic-twitter_full_uni_cbow_300_twitter.bin', '../../word_embeddings/arabic_embeddings/arabic-wiki_full_uni_cbow_300_wiki.bin', '../../word_embeddings/arabic_embeddings/cc.ar.300.vec']
# word الأب not in embedding
# word الأخ not in embedding
# word الأبناء not in embedding
# word الآباء not in embedding
# word الأولاد not in embedding
# word الإخوة not in embedding
# word خبير إحصائي not in embedding
# word قابلة not in embedding
# word محضّر not in embedding
# word صانع أحذية not in embedding
# word أمين صندوق not in embedding
# word راقصة not in embedding
# word مدبرة منزل not in embedding
# word طبيب أسنان not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word مدير مكتب بريد not in embedding
# word أمين مكتبة not in embedding
# word  موسيقي  not in embedding
# word  حمال  not in embedding
# word  عالم  not in embedding
# word  نجار  not in embedding
# word  بحار  not in embedding
# word  مدرب  not in embedding
# word  شريف  not in embedding
# word  رائد  not in embedding
# word  مفتش  not in embedding
# word  ماسون  not in embedding
# word عامل تشغيل not in embedding
# word ممرضة not in embedding
# word رجل دين not in embedding
# word شرطة not in embedding
# word أستاذ not in embedding
# word ابنة not in embedding
# word أم not in embedding
# word امرأة not in embedding
# word فتاة not in embedding
# word أنثى not in embedding
# word أخت not in embedding
# word أمهات not in embedding
# word  نساء not in embedding
# word المنيعة not in embedding
# word الأخوات not in embedding
# word العمة not in embedding
# word الأخوات not in embedding
# word الأخوات not in embedding
# word خبير إحصائي not in embedding
# word قابلة not in embedding
# word محضّر not in embedding
# word صانع أحذية not in embedding
# word أمين صندوق not in embedding
# word راقصة not in embedding
# word مدبرة منزل not in embedding
# word طبيب أسنان not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word مدير مكتب بريد not in embedding
# word أمين مكتبة not in embedding
# word  موسيقي  not in embedding
# word  حمال  not in embedding
# word  عالم  not in embedding
# word  نجار  not in embedding
# word  بحار  not in embedding
# word  مدرب  not in embedding
# word  شريف  not in embedding
# word  رائد  not in embedding
# word  مفتش  not in embedding
# word  ماسون  not in embedding
# word عامل تشغيل not in embedding
# word ممرضة not in embedding
# word رجل دين not in embedding
# word شرطة not in embedding
# word أستاذ not in embedding
# {'arabic-twitter_full_uni_cbow_300_twitter.bin': {'professional_occupation': {'male': {'حداد': 1.0668144226074219, 'جامع': 1.0489193610846996, 'بستاني': 0.983111472800374, 'وسيط': 0.981173649430275, 'كتابي': 0.9793276637792587, 'مبيعات': 0.9790287148207426, 'كاتب': 0.9581620022654533, 'جيولوجي': 0.9527161680161953, 'موصل': 0.9480033852159977, 'مزارع': 0.947241548448801,
# word عالم رياضيات not in embedding
# word مدير مكتب بريد not in embedding
# word أمين مكتبة not in embedding
# word  موسيقي  not in embedding
# word  حمال  not in embedding
# word  عالم  not in embedding
# word  نجار  not in embedding
# word  بحار  not in embedding
# word  مدرب  not in embedding
# word  شريف  not in embedding
# word  رائد  not in embedding
# word  مفتش  not in embedding
# word  ماسون  not in embedding
# word عامل تشغيل not in embedding
# word ممرضة not in embedding
# word رجل دين not in embedding
# word شرطة not in embedding
# word أستاذ not in embedding
# word ابنة not in embedding
# word أم not in embedding
# word امرأة not in embedding
# word فتاة not in embedding
# word أنثى not in embedding
# word أخت not in embedding
# word أمهات not in embedding
# word  نساء not in embedding
# word المنيعة not in embedding
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأب' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأخ' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأبناء' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الآباء' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأولاد' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الإخوة' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'ابنة' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أم' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'امرأة' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'فتاة' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أنثى' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أخت' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'أمهات' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word ' نساء' not in vocabulary"
# word الأخوات not in embedding
# word العمة not in embedding
# word الأخوات not in embedding
# word الأخوات not in embedding
# word خبير إحصائي not in embedding
# word قابلة not in embedding
# word محضّر not in embedding
# word مزايد not in embedding
# word صانع أحذية not in embedding
# word أمين صندوق not in embedding
# word راقصة not in embedding
# word مدبرة منزل not in embedding
# word طبيب أسنان not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word مدير مكتب بريد not in embedding
# word أمين مكتبة not in embedding
# word  موسيقي  not in embedding
# word  حمال  not in embedding
# word  عالم  not in embedding
# word  نجار  not in embedding
# word  بحار  not in embedding
# word  مدرب  not in embedding
# word  شريف  not in embedding
# word  رائد  not in embedding
# word  مفتش  not in embedding
# word  ماسون  not in embedding
# word عامل تشغيل not in embedding
# word ممرضة not in embedding
# word رجل دين not in embedding
# word شرطة not in embedding
# word أستاذ not in embedding
# {'arabic-twitter_full_uni_cbow_300_twitter.bin': {'professional_occupation': {'male': {'حداد': 1.0668144226074219, 'جامع': 1.0489193610846996, 'بستاني': 0.983111472800374, 'وسيط': 0.981173649430275, 'كتابي': 0.9793276637792587, 'مبيعات': 0.9790287148207426, 'كاتب': 0.9581620022654533, 'جيولوجي': 0.9527161680161953, 'موصل': 0.9480033852159977, 'مزارع': 0.947241548448801, 'مزايد': 0.942734282463789, 'جراح': 0.9417673386633396, 'مصور': 0.9390016160905361, 'محاسب': 0.9303497672080994, 'سكرتير': 0.9094494506716728, 'مهندس': 0.8965169042348862, 'قاضي': 0.8954010009765625, 'معلم': 0.8948775976896286, 'رسام': 0.8922971561551094, 'مسؤول': 0.892010860145092, 'مدير': 0.8862872496247292, 'مشرف': 0.882201112806797, 'متقاعد': 0.8808395713567734, 'خياط': 0.8733602315187454, 'جندي': 0.8704032301902771, 'طبخ': 0.8697479367256165, 'مساح': 0.8607020229101181, 'خباز': 0.859876736998558, 'اقتصادي': 0.8570444285869598, 'رياضي': 0.8544437140226364, 'مصمم': 0.8495466262102127, 'فيزيائي': 0.8481190502643585, 'محام': 0.8355546295642853, 'فنان': 0.8313004374504089, 'طالب': 0.8293042778968811, 'كيميائي': 0.8240521401166916, 'عامل': 0.8211714327335358, 'طبيب': 0.8173520863056183, 'حارس': 0.79831263422966, 'ميكانيكي': 0.7965361475944519, 'حائك': 0
not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأخوات' not in vocabulary"
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word 'الأخوات' not in vocabulary"
# word خبير إحصائي not in embedding
# word صانع أحذية not in embedding
# word أمين صندوق not in embedding
# word مدبرة منزل not in embedding
# word طبيب أسنان not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word مدير مكتب بريد not in embedding
# word أمين مكتبة not in embedding
# word  موسيقي  not in embedding
# word  حمال  not in embedding
# word  عالم  not in embedding
# word  نجار  not in embedding
# word  بحار  not in embedding
# word  مدرب  not in embedding
# word  شريف  not in embedding
# word  رائد  not in embedding
# word  مفتش  not in embedding
# word  ماسون  not in embedding
# word عامل تشغيل not in embedding
# word رجل دين not in embedding
# word  نساء not in embedding
# word خبير إحصائي not in embedding
# word صانع أحذية not in embedding
# word أمين صندوق not in embedding
# word مدبرة منزل not in embedding
# word طبيب أسنان not in embedding
# word عالم نفسي not in embedding
# word عالم رياضيات not in embedding
# word مدير مكتب بريد not in embedding
# word أمين مكتبة not in embedding
# word  موسيقي  not in embedding
# word  حمال  not in embedding
# word  عالم  not in embedding
# word  نجار  not in embedding
# word  بحار  not in embedding
# word  مدرب  not in embedding
# word  شريف  not in embedding
# word  رائد  not in embedding
# word  مفتش  not in embedding
# word  ماسون  not in embedding
# word عامل تشغيل not in embedding
# word رجل دين not in embedding
# {'arabic-twitter_full_uni_cbow_300_twitter.bin': {'professional_occupation': {'male': {'حداد': 1.0668144226074219, 'جامع': 1.0489193610846996, 'بستاني': 0.983111472800374, 'وسيط': 0.981173649430275, 'كتابي': 0.9793276637792587, 'مبيعات': 0.9790287148207426, 'كاتب': 0.9581620022654533, 'جيولوجي': 0.9527161680161953, 'موصل': 0.9480033852159977, 'مزارع': 0.947241548448801, 'مزايد': 0.942734282463789, 'جراح': 0.9417673386633396, 'مصور': 0.9390016160905361, 'محاسب': 0.9303497672080994, 'سكرتير': 0.9094494506716728, 'مهندس': 0.8965169042348862, 'قاضي': 0.8954010009765625, 'معلم': 0.8948775976896286, 'رسام': 0.8922971561551094, 'مسؤول': 0.892010860145092, 'مدير': 0.8862872496247292, 'مشرف': 0.882201112806797, 'متقاعد': 0.8808395713567734, 'خياط': 0.8733602315187454, 'جندي': 0.8704032301902771, 'طبخ': 0.8697479367256165, 'مساح': 0.8607020229101181, 'خباز': 0.859876736998558, 'اقتصادي': 0.8570444285869598, 'رياضي': 0.8544437140226364, 'مصمم': 0.8495466262102127, 'فيزيائي': 0.8481190502643585, 'محام': 0.8355546295642853, 'فنان': 0.8313004374504089, 'طالب': 0.8293042778968811, 'كيميائي': 0.8240521401166916, 'عامل': 0.8211714327335358, 'طبيب': 0.8173520863056183, 'حارس': 0.79831263422966, 'ميكانيكي': 0.7965361475944519, 'حائك': 0.7756747156381607, 'سائق': 0.7735966444015503, 'سميث': 0.7560823708772659}, 'female': {'جامع': 1.1434482485055923, 'محام': 1.0724889263510704, 'جيولوجي': 1.0636841729283333, 'رسام': 1.0428850501775742, 'جراح': 1.0388141982257366, 'قاضي': 1.0382056534290314, 'متقاعد': 1.0299073494970798, 'مسؤول': 1.0273340828716755, 'فيزيائي': 1.0212931875139475, 'مساح': 1.0192913934588432, 'جندي': 1.0186086595058441, 'وسيط': 1.0136468429118395, 'مشرف': 1.007957342080772, 'كاتب': 1.002366949338466, 'مدير': 1.0022661045659333, 'كتابي': 0.9980788677930832, 'مصور': 0.9960501356981695, 'طالب': 0.9958482193760574, 'طبيب': 0.9944904572330415, 'موصل': 0.9939201804809272, 'سكرتير': 0.992894867900759, 'بستاني': 0.9885914195328951, 'فنان': 0.9734210949391127, 'محاسب': 0.9703440945595503, 'حائك': 0.9613998904824257, 'حداد': 0.9585663489997387, 'مهندس': 0.9531998410820961, 'رياضي': 0.9469341896474361, 'معلم': 0.9458340331912041, 'كيميائي': 0.9452833011746407, 'حارس': 0.9446161054074764, 'سائق': 0.9436886049807072, 'مصمم': 0.9424483776092529, 'سميث': 0.9239521473646164, 'اقتصادي': 0.9144882410764694, 'خباز': 0.9134975746273994, 'مزايد': 0.9116065874695778, 'مبيعات': 0.8997751027345657, 'عامل': 0.8964065909385681, 'ميكانيكي': 0.895622231066227, 'مزارع': 0.8768120408058167, 'خياط': 0.8232190012931824, 'طبخ': 0.7211472690105438}}}, 'arabic-wiki_full_uni_cbow_300_wiki.bin': {'professional_occupation': {'male': {'مزارع': 1.0778306797146797, 'جيولوجي': 1.0675326362252235, 'اقتصادي': 1.0467255115509033, 'مبيعات': 1.0274418480694294, 'مدير': 1.0087858261540532, 'مساح': 1.0032131897751242, 'حداد': 1.0011977261165157, 'رياضي': 0.9877825416624546, 'مشرف': 0.9834388177841902, 'جامع': 0.9825180545449257, 'سكرتير': 0.9716439880430698, 'مهندس': 0.9634004458785057, 'جندي': 0.9367343336343765, 'فيزيائي': 0.9330558255314827, 'عامل': 0.9192129820585251, 'موصل': 0.90555389970541, 'كيميائي': 0.9032886028289795, 'خياط': 0.9024778455495834, 'مصور': 0.8996349275112152, 'مسؤول': 0.8930351883172989, 'محاسب': 0.891404964029789, 'متقاعد': 0.8900598734617233, 'قاضي': 0.8882313892245293, 'طالب': 0.8879380822181702, 'رسام': 0.8784275054931641, 'سميث': 0.8724193274974823, 'مصمم': 0.8712316900491714, 'طبخ': 0.8621000647544861, 'ميكانيكي': 0.8590516895055771, 'جراح': 0.8505672961473465, 'حائك': 0.8501995354890823, 'كاتب': 0.8452900350093842, 'فنان': 0.8366711735725403, 'وسيط': 0.8193810731172562, 'حارس': 0.8183926790952682, 'طبيب': 0.8073172122240067, 'معلم': 0.8062640428543091, 'سائق': 0.799646645784378, 'محام': 0.7763990759849548, 'بستاني': 0.7632665187120438, 'خباز': 0.7621777504682541, 'كتابي': 0.73860102891922}, 'female': {'رسام': 1.16553096473217, 'مصور': 1.1572709679603577, 'مشرف': 1.14137601852417, 'مهندس': 1.132513016462326, 'مساح': 1.1225231438875198, 'جراح': 1.112824 ...
# Traceback (most recent call last):
#   File "../calculate_distance.py", line 31, in __get_group_centroid
#     word_vector = model.get_vector(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 471, in get_vector
#     return self.word_vec(word)
#   File "/root/miniconda3/envs/ner/lib/python3.6/site-packages/gensim/models/keyedvectors.py", line 468, in word_vec
#     raise KeyError("word '%s' not in vocabulary" % word)
# KeyError: "word ' نساء' not in vocabulary"

# %% [markdown]
# ## Calculate bias

# %%
from plot_utils import get_bias_plot
female_bias_dict_for_all_embeddings = calculate_bias_for_all_embedding(association_dict=association_dict, 
                                                                     target_label = target_group_labels[0], 
                                                                     reference_labels = reference_group_labels)

get_bias_plot(bias_dict=female_bias_dict_for_all_embeddings, b2e_dict=b2e_dict, bias_label = reference_group_labels[1])

# %% [markdown]
# ## Correlation Heatmap

# %%
import pandas as pd
df = pd.DataFrame.from_dict(female_bias_dict_for_all_embeddings)
get_correlation_heatmap(df=df)
